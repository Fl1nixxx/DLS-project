# %%
# !pip install streamlit -q

# %%
# !git clone https://github.com/Fl1nixxx/DLS-project
# %cd /content/DLS-project

# !streamlit run app.py \
  --server.address 0.0.0.0 \
  --server.port 8501 \
  --server.headless true \
  > streamlit.log 2>&1 &

# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared
# !./cloudflared tunnel --url http://localhost:8501
# Out:
# Cloning into 'DLS-project'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 9.80 KiB | 1.63 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/DLS-project
# 2026-06-07T15:30:08Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-06-07T15:30:08Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-06-07T15:30:14Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-07T15:30:14Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-06-07T15:30:14Z INF |  https://invision-antibody-reduce-criticism.trycloudflare.com                              |
# 2026-06-07T15:30:14Z INF +--------------------------------------------------------------------------------------------+
# 2026-06-07T15:30:14Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-06-07T15:30:14Z INF Version 2026.5.2 (Checksum 5286698547f03df745adb2355f04c12dde52ef425491e81f433642d695521886)
# 2026-06-07T15:30:14Z INF GOOS: linux, GOVersion: go1.26.3, GoArch: amd64
# 2026-06-07T15:30:14Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-06-07T15:30:14Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-06-07T15:30:14Z INF Generated Connector ID: 479bdddd-6e24-4517-96e6-2f584e71ff13
# 2026-06-07T15:30:14Z INF Initial protocol quic
# 2026-06-07T15:30:14Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-07T15:30:14Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/06/07 15:30:14 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-06-07T15:30:14Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-06-07T15:30:14Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-06-07T15:30:14Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-06-07T15:30:14Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.227
# 2026-06-07T15:30:14Z INF Registered tunnel connection connIndex=0 connection=73fa469d-533e-410b-8203-76de0c920b5b event=0 ip=198.41.192.227 location=ams21 protocol=quic
# 2026-06-07T15:30:20Z INF +-------------------------------------------------------------------------------------+
# 2026-06-07T15:30:20Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-06-07T15:30:20Z INF +-------------------------------------------------------------------------------------+
# 2026-06-07T15:30:20Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-06-07T15:30:20Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-07T15:30:20Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-06-07T15:30:20Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-07T15:30:20Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-06-07T15:30:20Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-07T15:30:20Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-06-07T15:30:20Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-06-07T15:30:20Z INF |                                                                                     |
# 2026-06-07T15:30:20Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-06-07T15:30:20Z INF +-------------------------------------------------------------------------------------+
# 2026-06-07T15:30:20Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region1.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region2.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region1.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region2.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region1.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=region2.v2.argotunnel.com
# 2026-06-07T15:30:20Z INF precheck component="Cloudflare API" details="API is reachable" run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 status=pass target=api.cloudflare.com:443
# 2026-06-07T15:30:20Z INF precheck complete hard_fail=false run_id=abd5e89b-0c86-4f2c-a60b-f6e72a9c0798 suggested_protocol=quic
# 2026-06-07T15:33:18Z INF Initiating graceful shutdown due to signal interrupt ...
# 2026-06-07T15:33:18Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.227
# 2026-06-07T15:33:18Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.227
# 2026-06-07T15:33:18Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.227
# 2026-06-07T15:33:18Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.227
# 2026-06-07T15:33:18Z ERR Connection terminated connIndex=0
# 2026-06-07T15:33:18Z ERR no more connections active and exiting
# 2026-06-07T15:33:18Z INF Tunnel server stopped
# 2026-06-07T15:33:18Z INF Metrics server stopped
